# %% [markdown]
# ## This is a example of how you will be doing projects in python.
# ### Use markdown cells -OR- comments in cells to place AT LEAST the question number you are working on.

# %% [markdown]
# 3.	Import the required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 4. Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2023  1992.424394              NaN
# 1     Afghanistan  2022  1981.710168              NaN
# 2     Afghanistan  2021  2144.166570              NaN
# 3     Afghanistan  2020  2769.685745              NaN
# 4     Afghanistan  2019  2927.245144              NaN

# %% [markdown]
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column?

# %%
print("Shape of the DataFrame:", gdp_df.shape)
print("\nData types of each column:")
print(gdp_df.dtypes)
# Out:
# Shape of the DataFrame: (8219, 4)
#
# Data types of each column:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8219 entries, 0 to 8218
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  8219 non-null   object
#  1   Year             8219 non-null   int64
#  2   Value            8219 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 257.0+ KB

# %% [markdown]
# 6. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'.

# %%
gdp_df.drop('Value Footnotes', axis=1, inplace=True)
gdp_df
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2023  1992.424394
# 1        Afghanistan  2022  1981.710168
# 2        Afghanistan  2021  2144.166570
# 3        Afghanistan  2020  2769.685745
# 4        Afghanistan  2019  2927.245144
# ...              ...   ...          ...
# 8214        Zimbabwe  1994  3965.730986
# 8215        Zimbabwe  1993  3634.750494
# 8216        Zimbabwe  1992  3649.891947
# 8217        Zimbabwe  1991  4126.405247
# 8218        Zimbabwe  1990  4013.299059
#
# [8219 rows x 3 columns]

# %%
gdp_df.rename(columns={'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'}, inplace=True)
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2023     1992.424394
# 1     Afghanistan  2022     1981.710168
# 2     Afghanistan  2021     2144.166570
# 3     Afghanistan  2020     2769.685745
# 4     Afghanistan  2019     2927.245144
# ...           ...   ...             ...
# 8214     Zimbabwe  1994     3965.730986
# 8215     Zimbabwe  1993     3634.750494
# 8216     Zimbabwe  1992     3649.891947
# 8217     Zimbabwe  1991     4126.405247
# 8218     Zimbabwe  1990     4013.299059
#
# [8219 rows x 3 columns]

# %% [markdown]
# 7. How many countries have data for all years? Which countries are missing many years of data? Look at the number of observations per year. What do you notice?

# %%
all_years = gdp_df['Year'].nunique()


country_year_counts = gdp_df.groupby('Country')['Year'].nunique()


complete_countries = country_year_counts[country_year_counts == all_years]
num_complete_countries = complete_countries.count()

print(f"✅ Number of countries with data for all {all_years} years: {num_complete_countries}")
# Out:
# ✅ Number of countries with data for all 34 years: 228

# %% [markdown]
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020. Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

years = gdp_df['Year']

GDP_per_capita_2020 = gdp_df[years == 2020]["GDP_Per_Capita"]

GDP_per_capita_2020 = pd.to_numeric(GDP_per_capita_2020, errors='coerce')
gdp_df = gdp_df.dropna()


fig, axes = plt.subplots(2, 2, figsize=(14, 10))


sns.histplot(GDP_per_capita_2020, bins=20, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title("Histogram")


sns.kdeplot(GDP_per_capita_2020, ax=axes[0, 1], fill=True, color='lightcoral')
axes[0, 1].set_title("Density Plot (KDE)")


sns.boxplot(x=GDP_per_capita_2020, ax=axes[1, 0], color='lightgreen')
axes[1, 0].set_title("Boxplot")


sns.violinplot(x=GDP_per_capita_2020, ax=axes[1, 1], color='lightpink')
axes[1, 1].set_title("Violin Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# 9. What was the median GDP per capita value in 2020?

# %%
median_gdp = GDP_per_capita_2020.median()
print("Median GDP per capita in 2020:", round(median_gdp, 2))
# Out:
# Median GDP per capita in 2020: 15309.24

# %% [markdown]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:
# 	* A boxplot
# 	* A barplot (check out the Barplot with Seaborn section: https://www.python-graph-gallery.com/barplot/#Seaborn)
# 	* A scatterplot
# 	* A scatterplot with a trend line overlaid (see this regplot example: https://www.python-graph-gallery.com/42-custom-linear-regression-fit-seaborn)
# Comment on what you observe has happened to GDP values over time and the relative strengths and weaknesses of each type of plot.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

gdp_decades = gdp_df[gdp_df['Year'].isin([1990, 2000, 2010, 2020])]

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

sns.boxplot(data=gdp_decades, x='Year', y='GDP_Per_Capita', hue='Year', legend=False, ax=axes[0, 0], palette='pastel')
axes[0, 0].set_title("Boxplot of GDP per Capita by Year")
axes[0, 0].set_xlabel("Year")
axes[0, 0].set_ylabel("GDP per Capita (USD)")


sns.barplot(data=gdp_decades, x='Year', y='GDP_Per_Capita', estimator=np.mean, hue='Year', legend=False, ax=axes[0, 1], palette='muted')
axes[0, 1].set_title("Barplot of Average GDP per Capita by Year")
axes[0, 1].set_xlabel("Year")
axes[0, 1].set_ylabel("Average GDP per Capita (USD)")


sns.stripplot(data=gdp_decades, x='Year', y='GDP_Per_Capita', hue='Year', legend=False, jitter=True, alpha=0.7, ax=axes[1, 0], palette='deep')
axes[1, 0].set_title("Scatterplot of GDP per Capita by Year")
axes[1, 0].set_xlabel("Year")
axes[1, 0].set_ylabel("GDP per Capita (USD)")


sns.regplot(data=gdp_decades, x='Year', y='GDP_Per_Capita', scatter_kws={'alpha': 0.7}, ax=axes[1, 1])
axes[1, 1].set_title("Scatterplot with Trend Line (Regplot)")
axes[1, 1].set_xlabel("Year")
axes[1, 1].set_ylabel("GDP per Capita (USD)")

plt.tight_layout()
plt.show()

# %% [markdown]
# 11. Which country was the first to have a GDP per capita greater than $100,000?

# %%
print(gdp_df.columns)
# Out:
# Index(['Country', 'Year', 'GDP_Per_Capita'], dtype='object')

# %%
high_gdp = gdp_df[gdp_df['GDP_Per_Capita'] > 100000]
first_high_gdp = high_gdp.sort_values(by='Year').head(1)
print(first_high_gdp)
# Out:
#                    Country  Year  GDP_Per_Capita
# 7827  United Arab Emirates  1990   108057.042464

# %% [markdown]
# 12. Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]
top_country_row = gdp_2020.loc[gdp_2020['GDP_Per_Capita'].idxmax()]
top_country = top_country_row['Country']
print('Highest GDP per capita in 2020', top_country)

import matplotlib.pyplot as plt
import seaborn as sns

top_country_data = gdp_df[gdp_df['Country'] == top_country]
plt.figure(figsize=(10, 6))
sns.lineplot(data=top_country_data, x='Year', y='GDP_Per_Capita')
plt.title(f"GDP per Capita Over Time: {top_country}")
plt.xlabel("Year")
plt.ylabel("GDP per Capita (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Highest GDP per capita in 2020 Luxembourg

# %% [markdown]
# 13. Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset. **Bonus question:** Is it true in general that coutries had a higher GDP per capita in 2020 than in 1990? Which countries had lower GDP per capita in 2020 than in 1990

# %%
gdp_2020 = gdp_df[gdp_df['Year'] == 2020]
lowest_gdp_row = gdp_2020.loc[gdp_2020['GDP_Per_Capita'].idxmin()]
lowest_country = lowest_gdp_row['Country']
print("Lowest GDP per capita in 2020:", lowest_country)

lowest_country_data = gdp_df[gdp_df['Country'] == lowest_country]

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.lineplot(data=lowest_country_data, x='Year', y='GDP_Per_Capita')
plt.title(f"GDP per Capita Over Time: {lowest_country}")
plt.xlabel("Year")
plt.ylabel("GDP per Capita (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Lowest GDP per capita in 2020: Burundi

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named `internet_df`. You will likely get errors when doing this. Check the arguments for the read_csv function to find ones that can help correct the errors (https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns

# %%
internet_df = pd.read_csv('../data/internet_use.csv', on_bad_lines='skip')
internet_df
# Out:
#      Country or Area                                               Year  \
# 0        Afghanistan                                               2019
# 1        Afghanistan                                               2018
# 2        Afghanistan                                               2017
# 3        Afghanistan                                               2016
# 4        Afghanistan                                               2015
# ...              ...                                                ...
# 6375             293  Estimated based on Survey's results. Populatio...
# 6376             294                     Preliminary. Country estimate.
# 6377             295                                 18+. ITU estimate.
# 6378             296                     ICT survey. Population age 11+
# 6379             297  Internet users aged 3 years and above who used...
#
#       Value Value Footnotes
# 0     17.60               1
# 1     16.80               2
# ...

# %% [markdown]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'

# %%
internet_df = internet_df.drop(columns=['Value Footnotes'])
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
print(internet_df.head())
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2019               17.60
# 1  Afghanistan  2018               16.80
# 2  Afghanistan  2017               13.50
# 3  Afghanistan  2016               11.00
# 4  Afghanistan  2015                8.26

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %%
internet_df['Year'] = pd.to_numeric(internet_df['Year'], errors='coerce')
internet_df = internet_df.dropna(subset=['Year'])
internet_df['Year'] = internet_df['Year'].astype(int)
year_counts = internet_df['Year'].value_counts().sort_index()
internet_df = internet_df[internet_df['Year'] != 0]
print(year_counts)
# Out:
# Year
# 0         3
# 1990    226
# 1991     39
# 1992     50
# 1993     66
# 1994     92
# 1995    141
# 1996    177
# 1997    188
# 1998    195
# 1999    207
# 2000    210
# 2001    212
# 2002    214
# 2003    208
# 2004    210
# 2005    212
# 2006    212
# 2007    217
# 2008    214
# 2009    214
# 2010    209
# 2011    214
# 2012    209
# 2013    203
# 2014    204
# 2015    203
# 2016    206
# 2017    205
# 2018    174
# 2019    185
# 2020    186
# 2021    186
# 2022    184
# 2023     11
# Name: count, dtype: int64

# %% [markdown]
# From 1990 to around 2021, you have a strong and consistent number of observations per year — usually around 200+ countries/entries.
# This suggests solid data coverage over the past 30+ years.
# 2023 has only 11 observations:
# This probably means data for 2023 is still incomplete or being collected.
#
# 2022 and 2021 have slightly fewer entries than earlier years:
# Could indicate some data collection delays due to events like the COVID-19 pandemic.

# %% [markdown]
# 17. What is the first year to have a non-zero internet users percentage value?

# %%
first_non_zero_year = internet_df[internet_df['Internet_Users_Pct'] > 0]['Year'].min()
print("The first year with a non-zero internet users percentage is:", first_non_zero_year)
# Out:
# The first year with a non-zero internet users percentage is: 1990

# %%
countries_1990 = internet_df[
    (internet_df['Year'] == 1990) & (internet_df['Internet_Users_Pct'] > 0)
][['Country', 'Internet_Users_Pct']].sort_values(by='Internet_Users_Pct', ascending=False)
print(countries_1990)
# Out:
#                            Country  Internet_Users_Pct
# 5810                 United States            0.784729
# 4197                        Norway            0.707299
# 5332                   Switzerland            0.595714
# 306                      Australia            0.585095
# 5299                        Sweden            0.584192
# 2001                       Finland            0.401088
# 1010                        Canada            0.361000
# 3980  Netherlands (Kingdom of the)            0.334387
# 339                        Austria            0.130369
# 2192                       Germany            0.125892
# 2796                        Israel            0.110774
# 1570                       Denmark            0.097277
# 5777                United Kingdom            0.087355
# 2034                        France            0.052778
# 3054          Korea (Republic  of)            0.023265
# 2892                         Japan            0.020294
# ...

# %%
import matplotlib.pyplot as plt
countries_1990 = internet_df[
    (internet_df['Year'] == 1990) & (internet_df['Internet_Users_Pct'] > 0)
][['Country', 'Internet_Users_Pct']].sort_values(by='Internet_Users_Pct', ascending=False)
plt.figure(figsize=(12, 6))
plt.bar(countries_1990['Country'], countries_1990['Internet_Users_Pct'])
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Internet Users (%)')
plt.title('Internet Users Percentage by Country in 1990')
plt.tight_layout()
plt.show()

# %% [markdown]
# 18. How does the distribution of internet users percent differ for 2000 and 2014?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_2000 = internet_df[internet_df['Year'] == 2000]
df_2014 = internet_df[internet_df['Year'] == 2014]
plt.figure(figsize=(12, 6))
sns.histplot(df_2000['Internet_Users_Pct'], color='blue', label='2000', kde=True, stat="density", bins=20)
sns.histplot(df_2014['Internet_Users_Pct'], color='green', label='2014', kde=True, stat="density", bins=20)
plt.title("Distribution of Internet Users Percentage in 2000 vs 2014")
plt.xlabel("Internet Users (%)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 19. For how many countries was the percentage of internet users below 5% in 2014?

# %%
low_access_2014 = internet_df[ (internet_df['Year'] == 2014) & (internet_df['Internet_Users_Pct'] < 5)]
print(low_access_2014[['Country', 'Internet_Users_Pct']].sort_values(by='Internet_Users_Pct'))
print("Number of countries with <5% internet users in 2014:", len(low_access_2014))
# Out:
#                                Country  Internet_Users_Pct
# 1782                           Eritrea             0.99000
# 873                            Burundi             1.04239
# 4073                             Niger             1.24868
# 5055                           Somalia             1.63000
# 5116                       South Sudan             2.60000
# 1033          Central African Republic             2.70000
# 1061                              Chad             2.90000
# 1517  Democratic Republic of the Congo             3.00000
# 2451                     Guinea-Bissau             3.32000
# 3364                        Madagascar             3.70000
# Number of countries with <5% internet users in 2014: 10

# %% [markdown]
# 20. Merge the two DataFrames to one. Do this in a way that keeps **all rows** from each of the two DataFrames. Call the new DataFrame `gdp_and_internet_use`. Look at the first and last few rows to confirm that it merged correctly.

# %%
gdp_and_internet_use = pd.merge(gdp_df, internet_df, how='outer', on=['Country', 'Year'])
print(gdp_and_internet_use.head())
print(gdp_and_internet_use.tail())
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  1990             NaN            0.000000
# 1  Afghanistan  2000     1617.826475                 NaN
# 2  Afghanistan  2001     1454.110782            0.004723
# 3  Afghanistan  2002     1774.308743            0.004561
# 4  Afghanistan  2003     1815.928200            0.087891
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 9494  Zimbabwe  2019     3294.806084             26.5883
# 9495  Zimbabwe  2020     2987.269823             29.2986
# 9496  Zimbabwe  2021     3184.785451             32.4616
# 9497  Zimbabwe  2022     3323.121932             32.5615
# 9498  Zimbabwe  2023     3442.251327                 NaN

# %% [markdown]
# 21. Find the three countries with the highest internet users percentage in 2014. Use a seaborn FacetGrid (https://seaborn.pydata.org/generated/seaborn.FacetGrid.html) to compare how the GDP per capita has changed over time for these three countries. What do you notice?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_2014 = gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014]
top3_countries = df_2014.sort_values(by="Internet_Users_Pct", ascending=False).head(3)['Country'].tolist()
print("Top 3 countries in 2014 with highest internet usage:", top3_countries)

top3_data = gdp_and_internet_use[gdp_and_internet_use['Country'].isin(top3_countries)]

g = sns.FacetGrid(top3_data, col="Country", col_wrap=3, height=4, aspect=1.2)
g = g.map(sns.lineplot, "Year", "GDP_Per_Capita")
g.set_axis_labels("Year", "GDP per Capita (USD)")
g.set_titles("{col_name}")
plt.tight_layout()
plt.show()
# Out:
# Top 3 countries in 2014 with highest internet usage: ['Iceland', 'Falkland (Malvinas) Islands', 'Bermuda']

# %% [markdown]
# 22. Subset `gdp_and_internet_use` to just the year 2014. Save this as a new dataframe named `gdp_and_internet_use_2014`.

# %%
gdp_and_internet_use_2014 = gdp_and_internet_use[gdp_and_internet_use['Year'] == 2014]
print(gdp_and_internet_use_2014.head())
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15                   Afghanistan  2014     3017.942544                 7.0
# 49   Africa Eastern and Southern  2014     4052.851526                 NaN
# 83    Africa Western and Central  2014     4816.917355                 NaN
# 117                      Albania  2014    12788.747231                54.3
# 151                      Algeria  2014    15073.762940                29.5

# %% [markdown]
# 23. Create a plot which compares Internet Users Percentage and GDP per Capita for the year 2014. What do you notice from this plot? If you see any unusual points, investigate them.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 24. **Stretch Question:** Use the `qcut` function from pandas (https://pandas.pydata.org/docs/reference/api/pandas.qcut.html) to divide countries in `gdp_per_capita_2014` into three groups based on their GDP per capita values. Label these groups as "Low", "Medium", and "High". Put these labels in a new column, named "GDP_group".

# %%
gdp_per_capita_2014['GDP_group'] = pd.qcut(gdp_per_capita_2014['GDP_Per_Capita'], q=3,
labels=["Low", "Medium", "High"])
print(gdp_per_capita_2014.head())
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct  \
# 15                   Afghanistan  2014     3017.942544                 7.0
# 49   Africa Eastern and Southern  2014     4052.851526                 NaN
# 83    Africa Western and Central  2014     4816.917355                 NaN
# 117                      Albania  2014    12788.747231                54.3
# 151                      Algeria  2014    15073.762940                29.5
#
#     GDP_group
# 15        Low
# 49        Low
# 83        Low
# 117    Medium
# 151    Medium

# %% [markdown]
# 25. **Stretch Question:** How does the median internet users percentage compare for the three gdp groups?

# %%
median_internet_pct_by_gdp_group = gdp_per_capita_2014.groupby('GDP_group', observed=False)['Internet_Users_Pct'].median()
print(median_internet_pct_by_gdp_group)
# Out:
# GDP_group
# Low       11.6000
# Medium    44.5945
# High      75.9800
# Name: Internet_Users_Pct, dtype: float64

# %% [markdown]
# Bonus exercise:
#
# 1.    Download another data set from the UN data (http://data.un.org/Explorer.aspx) to merge with your data and explore.
